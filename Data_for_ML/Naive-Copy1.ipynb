# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import cross_val_score, KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import LeaveOneOut

# %%
#dev = pd.read_csv('https://github.com/xsam0510/Class_ex/blob/main/Data_for_ML/dev.csv?raw=True')
dev = pd.read_csv('dev.csv')

# %%
dev.head()
# Out:
#      group       KV37      LV469      LV861      LVX54      LV746      LV218  \
# 0   AD_MCI  29.275378  23.853495  24.376810  24.110526  27.073875  25.099886
# 1  Healthy  29.198232  23.940086  24.319879  21.760924  25.424342  25.079998
# 2       PD  27.646217  22.574600  24.151681  22.999830  26.228778  25.444026
# 3  Healthy  26.926440  22.001304  24.082716  21.344591  25.359814  24.043851
# 4   AD_MCI  28.093866  22.812714  26.303644  22.669820  25.478488  24.591364
#
#        LV316      LV312      LV310  ...      ARMD4      C1QT5      B2L12  \
# 0  24.022414  22.991551  23.088154  ...  17.758128  19.815044  27.084646
# 1  23.477187  22.419538  23.107371  ...  20.485457  18.768309  28.044557
# 2  22.426920  21.614212  21.701090  ...  19.686130  20.134751  27.485401
# 3  22.313657  21.683876  21.284550  ...  18.122531  19.800806  28.128446
# 4  23.190263  23.232873  22.715714  ...  19.355818  19.712294  28.532625
#
#        PLXA4      B3GN2      PCDGL      AGRB1       RECK       PSA1      F174A
# 0  18.043516  19.375124  17.866666  21.106636  18.228638  20.826409  24.088204
# 1  19.701435  18.063080  17.887599  21.533795  19.137712  20.268043  24.379025
# 2  17.511246  19.112400  16.677312  20.618581  18.904878  20.525042  24.137132
# 3  20.095204  20.287733  18.264954  21.070426  19.595288  20.398021  24.199453
# 4  19.111751  20.339691  19.078691  21.460532  19.894590  20.783830  24.078390
#
# [5 rows x 1139 columns]

# %%
# Encode the target variable
le = LabelEncoder()
dev['group'] = le.fit_transform(dev['group'])

# Split the data into features and target
X, y = dev.drop('group', axis=1), dev['group']

# Standardize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Create a Gaussian Naive Bayes model
nb = GaussianNB()

# Use LeaveOneOut cross-validation
loo = LeaveOneOut()

# Keep track of validation performance for each fold
accuracies = []

for train_idx, val_idx in loo.split(X):
    # Split the data into training and validation sets
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    
    # Fit the model to the training data
    nb.fit(X_train, y_train)

    # Make predictions on the validation data
    y_pred = nb.predict(X_val.reshape(1, -1))

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_val, y_pred)
    
    # Store the validation performance
    accuracies.append(accuracy)

# Calculate the mean validation performance over all folds
mean_accuracy = np.mean(accuracies)
print("Mean Accuracy:", mean_accuracy)
# Out:
# Mean Accuracy: 0.4831932773109244

# %% [markdown]
# This is the Naive Bayes model as function

# %%
def Naive_Bayes_model(dev):
    # Encode the target variable
    le = LabelEncoder()
    dev['group'] = le.fit_transform(dev['group'])

    X, y = dev.drop('group', axis=1), dev['group']

    # Standardize the data
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    # Create a Gaussian Naive Bayes model
    nb = GaussianNB()

    # Perform Leave-One-Out Cross-Validation
    loo = LeaveOneOut()
    
    # Keep track of validation performance for each fold
    accuracies = []
    for train_idx, val_idx in loo.split(X):
        # Split the data into training and validation sets
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        # Fit the model to the training data
        nb.fit(X_train, y_train)

        # Make predictions on the validation data
        y_pred = nb.predict(X_val)

        # Calculate the accuracy of the model
        accuracy = accuracy_score(y_val, y_pred)
        accuracies.append(accuracy)

    # Calculate the mean accuracy
    mean_accuracy = np.mean(accuracies)
    return print("Mean Accuracy:", mean_accuracy)

# %%
Naive_Bayes_model(dev)
# Out:
# Mean Accuracy: 0.4831932773109244
